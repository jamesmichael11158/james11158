# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mp
import seaborn as sns
sns.set()

births = pd.read_csv('births.csv')
births['decades'] = (births['year'] // 10) * 10

# Rhobust sigma clipping operation
quartiles = np.percentile(births['births'], [25, 50, 75])
mu = quartiles[1]
sig = 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')

births['day'] = births['day'].astype(int)
#births['day'].dtype

births.index = pd.to_datetime(10000 * births.year +
                             100 * births.month +
                             births.day, format='%Y%m%d')

births['dayofweek'] = births.index.dayofweek

#births.pivot_table('births', index = 'dayofweek',
#                  columns = 'decades', aggfunc = 'mean').plot()

#plt.gca().set_xticklabels(['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'])
#plt.ylabel('mean births by day')

births_by_date = births.pivot_table('births', [births.index.month, births.index.day])

#print(births_by_date.index)


births_by_date.index = [pd.datetime(2012, month, day)
                       for (month, day) in births_by_date.index]

#print(births_by_date.index)

fig, ax = plt.subplots(figsize=(12,4))
births_by_date.plot(ax=ax)

# %%
[(x, y) for x in range(1,30) for y in range(1,10) if y == 1/2 * x]
# Out:
# [(2, 1), (4, 2), (6, 3), (8, 4), (10, 5), (12, 6), (14, 7), (16, 8), (18, 9)]

# %%
for x in range(1, 30):
    for y in range(1, 10):
        if y == 1/2 * x:
            tup = (x, y)
            output.append(tup)
print(output)
# Out:
# [(2, 1), (4, 2), (6, 3), (8, 4), (10, 5), (12, 6), (14, 7), (16, 8), (18, 9), (2, 1), (4, 2), (6, 3), (8, 4), (10, 5), (12, 6), (14, 7), (16, 8), (18, 9), (2, 1), (4, 2), (6, 3), (8, 4), (10, 5), (12, 6), (14, 7), (16, 8), (18, 9)]
